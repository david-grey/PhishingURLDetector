# %%
from urllib.parse import urlparse
import re

import csv
import urllib
import urllib.request
from xml.dom import minidom
nf=-1

opener = urllib.request.build_opener()
opener.addheaders = [('User-agent', 'Mozilla/5.0')]



def Tokenise(url):

        if url=='':
            return [0,0,0]
        token_word=re.split('\W+',url)
        #print token_word
        no_ele=sum_len=largest=0
        for ele in token_word:
                l=len(ele)
                sum_len+=l
                if l>0:                                        ## for empty element exclusion in average length
                        no_ele+=1
                if largest<l:
                        largest=l
        try:
            return [float(sum_len)/no_ele,no_ele,largest]
        except:
            return [0,no_ele,largest]


def find_ele_with_attribute(dom,ele,attribute):
    for subelement in dom.getElementsByTagName(ele):
        if subelement.hasAttribute(attribute):
            return subelement.attributes[attribute].value
    return nf
        

def sitepopularity(host):

        xmlpath='http://data.alexa.com/data?cli=10&dat=snbamz&url='+host
        #print xmlpath
        try:
            xml= urllib.request.urlopen(xmlpath).read()
            dom =minidom.parseString(xml)
            rank_host=find_ele_with_attribute(dom,'REACH','RANK')
            #country=find_ele_with_attribute(dom,'REACH','RANK')
            rank_country=find_ele_with_attribute(dom,'COUNTRY','RANK')
            return [rank_host,rank_country]

        except:
            return [nf,nf]


def Security_sensitive(tokens_words):

    sec_sen_words=['confirm', 'account', 'banking', 'secure', 'ebayisapi', 'webscr', 'login', 'signin']
    cnt=0
    for ele in sec_sen_words:
        if(ele in tokens_words):
            cnt+=1;

    return cnt

def exe_in_url(url):
    if url.find('.exe')!=-1:
        return 1
    return 0





def web_content_features(url):
    wfeatures={}
    total_cnt=0
    try:        
        source_code = str(opener.open(url).read())
        #print source_code[:500]

        wfeatures['src_html_cnt']=source_code.count('<html')
        wfeatures['src_hlink_cnt']=source_code.count('<a href=')
        wfeatures['src_iframe_cnt']=source_code.count('<iframe')
        #suspicioussrc_ javascript functions count

        wfeatures['src_eval_cnt']=source_code.count('eval(')
        wfeatures['src_escape_cnt']=source_code.count('escape(')
        wfeatures['src_link_cnt']=source_code.count('link(')
        wfeatures['src_underescape_cnt']=source_code.count('underescape(')
        wfeatures['src_exec_cnt']=source_code.count('exec(')
        wfeatures['src_search_cnt']=source_code.count('search(')
        
        for key in wfeatures:
            if(key!='src_html_cnt' and key!='src_hlink_cnt' and key!='src_iframe_cnt'):
                total_cnt+=wfeatures[key]
        wfeatures['src_total_jfun_cnt']=total_cnt
    
    except Exception as e:
        print ("Error"+str(e)+" in downloading page "+url )
        default_val=nf
        
        wfeatures['src_html_cnt']=default_val
        wfeatures['src_hlink_cnt']=default_val
        wfeatures['src_iframe_cnt']=default_val
        wfeatures['src_eval_cnt']=default_val
        wfeatures['src_escape_cnt']=default_val
        wfeatures['src_link_cnt']=default_val
        wfeatures['src_underescape_cnt']=default_val
        wfeatures['src_exec_cnt']=default_val
        wfeatures['src_search_cnt']=default_val
        wfeatures['src_total_jfun_cnt']=default_val    
    
    return wfeatures
'''
def safebrowsing(url):
    api_key = "ABQIAAAA8C6Tfr7tocAe04vXo5uYqRTEYoRzLFR0-nQ3fRl5qJUqcubbrw"
    name = "URL_check"
    ver = "1.0"

    req = {}
    req["client"] = name
    req["apikey"] = api_key
    req["appver"] = ver
    req["pver"] = "3.0"
    req["url"] = url #change to check type of url

    try:
        params = urllib.urlencode(req)
        req_url = "https://sb-ssl.google.com/safebrowsing/api/lookup?"+params
        res = urllib2.urlopen(req_url)
        # print res.code
        # print res.read()
        if res.code==204:
            # print "safe"
            return 0
        elif res.code==200:
            # print "The queried URL is either phishing, malware or both, see the response body for the specific type."
            return 1
        elif res.code==204:
            print "The requested URL is legitimate, no response body returned."
        elif res.code==400:
            print "Bad Request The HTTP request was not correctly formed."
        elif res.code==401:
            print "Not Authorized The apikey is not authorized"
        else:
            print "Service Unavailable The server cannot handle the request. Besides the normal server failures, it could also indicate that the client has been throttled by sending too many requests"
    except:
        return -1
'''
def feature_extract(url_input):

        Feature={}
        tokens_words=re.split('\W+',url_input)       #Extract bag of words stings delimited by (.,/,?,,=,-,_)
        #print tokens_words,len(tokens_words)

        #token_delimit1=re.split('[./?=-_]',url_input)
        #print token_delimit1,len(token_delimit1)

        obj=urlparse(url_input)
        host=obj.netloc
        path=obj.path

        # Feature['URL']=url_input

        Feature['rank_host'],Feature['rank_country'] =sitepopularity(host)

        Feature['host']=obj.netloc
        Feature['path']=obj.path

        Feature['Length_of_url']=len(url_input)
        Feature['Length_of_host']=len(host)
        Feature['No_of_dots']=url_input.count('.')
        Feature["count_of_@"] = url_input.count('@')
   
        Feature["count_of_do"] = url_input.count('$')
        Feature["count_of_redirect"] = url_input.count('//') - ("://" in url_input)

        Feature['avg_token_length'],Feature['token_count'],Feature['largest_token'] = Tokenise(url_input)
        Feature['avg_domain_token_length'],Feature['domain_token_count'],Feature['largest_domain'] = Tokenise(host)
        Feature['avg_path_token'],Feature['path_token_count'],Feature['largest_path'] = Tokenise(path)

        Feature['sec_sen_word_cnt'] = Security_sensitive(tokens_words)

        if re.match(r'.*\d*\.\d*\.\d*\.\d*,*',str(host)) == None:
            Feature["ip_consist"] = 0
        else:
            Feature["ip_consist"] = 1
        
        # print host
        # print getASN(host)
        # Feature['exe_in_url']=exe_in_url(url_input)
        # Feature['ASNno']=getASN(host)
        # Feature['safebrowsing']=safebrowsing(url_input)
        wfeatures=web_content_features(url_input)
        
        for key in wfeatures:
            Feature[key]=wfeatures[key]
        
        #debug
        # for key in Feature:
        #     print key +':'+str(Feature[key])
        return Feature

# %%
feature_extract('http://www.lineqxt.cn/index.php/home/account/login')
# Out:
# {'Length_of_host': 14,
#  'Length_of_url': 50,
#  'No_of_dots': 3,
#  'avg_domain_token_length': 4.0,
#  'avg_path_token': 4.8,
#  'avg_token_length': 4.444444444444445,
#  'count_of_@': 0,
#  'count_of_do': 0,
#  'count_of_redirect': 0,
#  'domain_token_count': 3,
#  'host': 'www.lineqxt.cn',
#  'ip_consist': 0,
#  'largest_domain': 7,
#  'largest_path': 7,
#  'largest_token': 7,
#  'path': '/index.php/home/account/login',
#  'path_token_count': 5,
#  'rank_country': -1,
#  'rank_host': -1,
#  'sec_sen_word_cnt': 2,
#  'src_escape_cnt': 0,
#  'src_eval_cnt': 2,
#  'src_exec_cnt': 0,
#  'src_hlink_cnt': 3,
#  'src_html_cnt': 1,
#  'src_iframe_cnt': 0,
#  'src_link_cnt': 0,
#  'src_search_cnt': 0,
#  'src_total_jfun_cnt': 2,
#  'src_underescape_cnt': 0,
#  'token_count': 9}

# %%
opener.open("http://greyarea.ml").read()

# %%
ls = []
source = []
label = []
with open("data.csv","r", encoding='utf8') as data:
    csvfile = csv.reader(data)
    for row in csvfile:
        source.append(row)
        ls.append(feature_extract(row[0]))
        label.append(row[1])
# Out:
# Errorunknown url type: 'URL' in downloading page URL
# Error<urlopen error [Errno 11001] getaddrinfo failed> in downloading page http://shagali.com/shiro/437594df261a1e7222745388/confirm.php?ID=1&amp;myca/logon/us/action/LogonHandler?request_type=LogonHandler&amp;Face=en_US?377c93831503755c39f0e9aaa66b01e2&amp;path=/signin/?referrer
# Error<urlopen error [Errno 11002] getaddrinfo failed> in downloading page http://https-security.esy.es/recovery-chekpoint-login.html
# Error<urlopen error [Errno 11002] getaddrinfo failed> in downloading page http://sec-verifyfb-login-fbpages.esy.es/recovery-chekpoint-login.html
# Error<urlopen error [Errno 11002] getaddrinfo failed> in downloading page http://recever0076.esy.es/recovery-chekpoint-login.html
# ErrorHTTP Error 406: Not Acceptable in downloading page http://geekgamergirl.com/wp-admin/America/AOL/index-aol.html
# ErrorHTTP Error 406: Not Acceptable in downloading page http://beyondcolorzpainting.com/chima/AOL/aol.htm
# ErrorHTTP Error 404: Not Found in downloading page https://hentainarutogirls.com/EserviceMain/irs/ir/index.html
# ErrorHTTP Error 404: Not Found in downloading page http://freetoonz.com/EserviceMain/irs/ir/index.html
# Error<urlopen error [Errno 11002] getaddrinfo failed> in downloading page http://htpp-security.esy.es/recovery-chekpoint-login.html
# ErrorHTTP Error 406: Not Acceptable in downloading page http://www.poliformas.com.mx/deans/AOL/aol.htm
# ErrorHTTP Error 406: Not Acceptable in downloading page http://cambriatrails.org/accc/aol.htm
# Error<urlopen error [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond> in downloading page http://sreechaitanyacollege.org/new/update.htm
# Error<urlopen error [Errno 11002] getaddrinfo failed> in downloading page http://10654561521.esy.es/error3245562.html
# ErrorHTTP Error 404: Not Found in downloading page http://1000000696596.at.ua/654165415/100000085415415.html
# Error<urlopen error [Errno 11002] getaddrinfo failed> in downloading page http://kinecc8787.esy.es/
# ErrorHTTP Error 403: Forbidden in downloading page http://onlyincebu.com/wp-content/themes/twentyten/.b/
# Error<urlopen error [Errno 11001] getaddrinfo failed> in downloading page http://shop.ideamarketspa.cl/webapps/89220/websrc
# Error<urlopen error [Errno 11002] getaddrinfo failed> in downloading page http://cekpoint-loogin523.esy.es/recovery-chekpoint-login.html
# Error<urlopen error [Errno 11002] getaddrinfo failed> in downloading page http://locations-errors.esy.es/recovery-chekpoint-login.html
# ErrorHTTP Error 404: Not Found in downloading page http://www.oasidelsaleragusa.it/libraries/joomla/test/
# ErrorHTTP Error 404: Not Found in downloading page http://liftin.jp/teoaos/rak229393/rakyat.htm
# ErrorHTTP Error 404: Not Found in downloading page http://www.googledoc.patrickinfo.com/gduc/
# Error<urlopen error [Errno 11001] getaddrinfo failed> in downloading page http://gmail.silki.tk/ServiceAuth_419.html
# ErrorHTTP Error 404: Not Found in downloading page http://virutcham.net/images/team/Nab1/index1.php
# ErrorHTTP Error 404: Not Found in downloading page http://virutcham.net/images/team/Nab1/
# ErrorHTTP Error 404: Not Found in downloading page http://noid-project.de/ABN/index.html
# Error<urlopen error [Errno 11001] getaddrinfo failed> in downloading page http://deoppe.ga/dropbox/drive/
# Error<urlopen error [Errno 11001] getaddrinfo failed> in downloading page http://deoppe.gq/adobe/
# ErrorHTTP Error 406: Not Acceptable in downloading page http://internetperformance.net/form/logs.html
# Error<urlopen error [Errno 11001] getaddrinfo failed> in downloading page https://www.paypal.com-autority.info/signin/492a1/webapps
# Error<urlopen error [Errno 11001] getaddrinfo failed> in downloading page https://services.runescape.com-rz.cf/m=forum/forums.ws281,346,548,23129325,189
# Error<urlopen error [Errno 11001] getaddrinfo failed> in downloading page http://Tinyurl.com/pking131
# ErrorHTTP Error 406: Not Acceptable in downloading page http://bbj-charter.com/yyy/newaol/aol.htm
# ErrorHTTP Error 404: Not Found in downloading page http://www.macroerp.com.br/ccs/contrato/wmd/rev.html
# ErrorHTTP Error 406: Not Acceptable in downloading page http://thebridgema.com/tescobank.onlineaccountverificationtscbnk001/
# Error<urlopen error [Errno 11004] getaddrinfo failed> in downloading page http://directmyaccount.zapto.org/webapps/df568/websrc
# Error<urlopen error [Errno 11001] getaddrinfo failed> in downloading page http://paypal.com.security.unusual.activity.policy.agreement.resolutioncenteraccountunusualactivity.co.vu/webapps/0e8ef/websrc
# ErrorHTTP Error 404: Not Found in downloading page http://www.future2jago.com/2/free.php
# Error<urlopen error [Errno 11001] getaddrinfo failed> in downloading page http://fix.it.again.tony.alandalaaaaa.is-gone.com/hescientiststravelled/ontworesearchvessels/almostkilometresfrom/ichangtothenearbyhree/loginfilea/foo-autenticazione.php
# Error<urlopen error [Errno 11001] getaddrinfo failed> in downloading page http://nmj9c545i0796cnesm468903fdgdfg.890m.com/
# Error<urlopen error [Errno 11001] getaddrinfo failed> in downloading page http://www.sb45sybvw5ydf65retgyesw.890m.com/
# ErrorHTTP Error 403: Forbidden in downloading page http://activation-online-team-int.co.nf/online/activation/Service/Login.html
# Error<urlopen error [Errno 11001] getaddrinfo failed> in downloading page http://postesecurelogin.posta.it.bancaposta.foo-autenticazione.kbso6x2odrfxardogzbz2z0eefpdijgtkzxgmplq7qnxyrm5gdu94td8pibx.alandalaaaaa.is-gone.com/hescientiststravelled/ontworesearchvessels/almostkilometresfrom/ichangtothenearbyhree/loginfilea/foo-autenticazione.php
# Error<urlopen error [Errno 11001] getaddrinfo failed> in downloading page http://randomstring.alandalaaaaa.is-gone.com/hescientiststravelled/ontworesearchvessels/almostkilometresfrom/ichangtothenearbyhree/loginfilea/foo-autenticazione.php
# ErrorHTTP Error 406: Not Acceptable in downloading page http://majormixer.com/Consult/AdminPanel/index.php
# Error<urlopen error [Errno 11001] getaddrinfo failed> in downloading page http://postesecurelogin.posta.it.bancaposta.foo-autenticazione.f2rgerucilmkzq2rb0l5tej8pm6jbio4zlyggapsd1hurpvroxmi2lgybqaj.alandalaaaaa.is-gone.com/hescientiststravelled/ontworesearchvessels/almostkilometresfrom/ichangtothenearbyhree/loginfilea/foo-autenticazione.php
# Error<urlopen error [Errno 11001] getaddrinfo failed> in downloading page http://postesecurelogin.randomtring.alandalaaaaa.is-gone.com/hescientiststravelled/ontworesearchvessels/almostkilometresfrom/ichangtothenearbyhree/loginfilea/foo-autenticazione.php
# Error<urlopen error [Errno 11001] getaddrinfo failed> in downloading page http://postesecurelogin.foo-autenticazione.alandalaaaaa.is-gone.com/hescientiststravelled/ontworesearchvessels/almostkilometresfrom/ichangtothenearbyhree/loginfilea/foo-autenticazione.php
# Error<urlopen error [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond> in downloading page http://93.104.208.45/hescientiststravelled/ontworesearchvessels/almostkilometresfrom/ichangtothenearbyhree/loginfilea/foo-autenticazione.php
# Error<urlopen error [Errno 11001] getaddrinfo failed> in downloading page http://postesecurelogin.posta.it.bancaposta.foo-autenticazione.alandalaaaaa.is-gone.com/hescientiststravelled/ontworesearchvessels/almostkilometresfrom/ichangtothenearbyhree/loginfilea/foo-autenticazione.php
# Error<urlopen error [Errno 11001] getaddrinfo failed> in downloading page http://postesecurelogin.posta.it.bancaposta.foo-autenticazione.uw5wiujrf1jawn0a9qpdzycbdehktugeha1gv0xq18rnlqojxucwifyl06wt.alandalaaaaa.is-gone.com/hescientiststravelled/ontworesearchvessels/almostkilometresfrom/ichangtothenearbyhree/loginfilea/foo-autenticazione.php
# Error<urlopen error [Errno 11001] getaddrinfo failed> in downloading page http://alandalaaaaa.is-gone.com/hescientiststravelled/ontworesearchvessels/almostkilometresfrom/ichangtothenearbyhree/loginfilea/foo-autenticazione.php
# Error<urlopen error [Errno 11001] getaddrinfo failed> in downloading page http://paviipali.cf/webapps/5aa0a/websrc
# Error<urlopen error [Errno 11001] getaddrinfo failed> in downloading page http://paypal.com.security.unusual.activity.policy.agreement.resolutioncenteraccountunusualactivity.co.vu/webapps/0ea0f/websrc
# Error<urlopen error [Errno 11001] getaddrinfo failed> in downloading page http://payment-supp-port-gearnya-elect-ron-sho-pu-pd-ate-info.rma.tio-nrec-ipe-dis-pu.te.bestgearelectronjavaonproduct.com/webapps/b87ff/websrc
# Error<urlopen error [Errno 11002] getaddrinfo failed> in downloading page http://bobortersads009.esy.es/recovery-chekpoint-login.html
# Error<urlopen error [Errno 11002] getaddrinfo failed> in downloading page http://www.paypal.com-a5d44e3439b7e4d76a1447d3391e919d.validations.review/cgi/bank/
# Error<urlopen error [Errno 11001] getaddrinfo failed> in downloading page http://topestateagency.co.uk/signin-ebay-co-uk-ws-eBayISAPI-dllPx3/
# ErrorHTTP Error 404: Not Found in downloading page http://noingoaithatdanang.com/plugins/http/www-amazon/SSL-Secure/au-verification.htm
# ErrorHTTP Error 406: Not Acceptable in downloading page http://preparapg.com.br//dropbox2/Dropbox/doc-login/index.php
# Error<urlopen error [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond> in downloading page http://outlwebsaccesgq.ukit.me/
# Error<urlopen error [Errno 11002] getaddrinfo failed> in downloading page http://www.paypal.com-a5d44e3439b7e4d76a1447d3391e919d.validations.review/cgi/card/
# ErrorHTTP Error 500: Internal Server Error in downloading page http://www.jvzpopnotify.com/suntrustinc/suntrust/index.php
# ErrorHTTP Error 500: Internal Server Error in downloading page http://fiesinscricoes.com.br/6/microsoft/index.htm
# ErrorHTTP Error 404: Not Found in downloading page http://lifespecialityclinic.com/AOL/AOL_Mail.htm
# ErrorHTTP Error 406: Not Acceptable in downloading page http://theclimatemakers.com/downloader/Maged/Account_update.htm
# Error[WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond in downloading page http://jandjtravelbiz.com/tettlom/aol/
# ErrorHTTP Error 406: Not Acceptable in downloading page http://melaniechandruang.com/wizzy/index.htm
# Error<urlopen error [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond> in downloading page http://www.evandgfonthlystandardraser.com/domains/indexx.htm
# ErrorHTTP Error 404: Not Found in downloading page http://www.blefitscapeoldcommeanniea1dingto.com/setting/indexx.htm
# ErrorHTTP Error 404: Not Found in downloading page http://ykt.spbume.ru/wp-includes/js/tinymce/skins/wordpress/index.php
# ErrorHTTP Error 404: Not Found in downloading page http://realvaluepromoters.com/frank/Docusign/index.html
# Error<urlopen error [Errno 11002] getaddrinfo failed> in downloading page http://mix56564234.96.lt/motogp.php
# Error<urlopen error [Errno 11002] getaddrinfo failed> in downloading page http://paypal.com-miss.asia/
# Error<urlopen error [Errno 11001] getaddrinfo failed> in downloading page https://www.resolutioncenter-unusualactivity-policyagreement.com/webapps/4c96f/websrc
# Error<urlopen error [Errno 11001] getaddrinfo failed> in downloading page https://www.paypalresolutioncenter.com-suspiciousactivityprivacyccount.info/mpp/signin/b514/websrc
# Error<urlopen error [Errno 11001] getaddrinfo failed> in downloading page http://payment-supp-port-gear-best-elect-ron-sho-pu-pd-ate-info.rma.tio-nrec-ipe-dis-pu.te.bestgearaccesooryelectroncity.com/webapps/c6716/websrc
# Error<urlopen error [Errno 11001] getaddrinfo failed> in downloading page http://www.sign.secure-allert-manage-info-access.improve-support.com/signin/7e19/websrc
# Error<urlopen error [Errno 11004] getaddrinfo failed> in downloading page http://directmyaccount.zapto.org/webapps/3db05/websrc
# Error<urlopen error [Errno 11001] getaddrinfo failed> in downloading page http://limitedaccountaccess.com/paypal.com/webapps/06ef6/websrc
# Error<urlopen error [Errno 11004] getaddrinfo failed> in downloading page https://directmyaccount.zapto.org/webapps/28b81/websrc
# Error<urlopen error [Errno 11001] getaddrinfo failed> in downloading page http://payment-supp-port-gear-best-elect-ron-sho-pu-pd-ate-info.rma.tio-nrec-ipe-dis-pu.te.bestgearaccesooryelectroncity.com/webapps/4f322/websrc
# Error<urlopen error [Errno 11004] getaddrinfo failed> in downloading page https://directmyaccount.zapto.org/webapps/1a640/websrc
# Error<urlopen error [Errno 11001] getaddrinfo failed> in downloading page https://paypal.com.limitedaccountaccess.com/webapps/21f8a/websrc
# Error<urlopen error [Errno 11001] getaddrinfo failed> in downloading page https://resolveds-verification.com/mpp/signin/3c41/websrc
# Error<urlopen error [Errno 11004] getaddrinfo failed> in downloading page https://directmyaccount.zapto.org/webapps/90b98/websrc
# Error<urlopen error [Errno 11004] getaddrinfo failed> in downloading page http://directmyaccount.zapto.org/webapps/b54d2/websrc
# ErrorHTTP Error 404: Not Found in downloading page http://ni1193846_1.vweb02.nitrado.net/sa/
# ErrorHTTP Error 522: Origin Connection Time-out in downloading page http://uktaxcouncil2.fr/refundhmrc/index.php
# Error<urlopen error [Errno 11001] getaddrinfo failed> in downloading page https://www.paypalresolutioncenter.com-suspiciousactivityprivacyccount.info/mpp/signin/0c00/websrc
# Error<urlopen error [Errno 11001] getaddrinfo failed> in downloading page https://www.paypalservice.com-suspiciousactivityresolutioncenter.info/webapps/e02a2/websrc
# Error<urlopen error [Errno 11004] getaddrinfo failed> in downloading page https://directmyaccount.zapto.org/webapps/1cca4/websrc
# ErrorHTTP Error 406: Not Acceptable in downloading page http://wifeswap.info/picoama/bil.htm
# Error<urlopen error [Errno 11001] getaddrinfo failed> in downloading page https://services.runescape.com-rz.cf/m=forum/forums.ws162,376,284,32584387,2
# ErrorHTTP Error 502: Bad Gateway in downloading page http://env-8215021.j.dnr.kz/ROOT/LICENSE.php
# ErrorHTTP Error 404: Not Found in downloading page http://help-suppor-fb.clan.su/reconfirm-next.html
# ErrorHTTP Error 404: Not Found in downloading page http://www.artevideo.arq.br/www2.bb.portal.com.br/index.php
# Error<urlopen error [Errno 11001] getaddrinfo failed> in downloading page https://services.runescape.com-rz.ga/m=weblogin/loginform.ws897,627,268,42591997,215
# Error<urlopen error [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond> in downloading page https://secure.runescape.com-es.gq/m=forum/forums.ws729,373,219,51781943,43
# Error<urlopen error [Errno 11002] getaddrinfo failed> in downloading page http://ver1fy-acct0063.esy.es/recovery-chekpoint-login.html
# Error<urlopen error [Errno 11002] getaddrinfo failed> in downloading page http://apps-security.esy.es/recovery-chekpoint-login.html
# Error<urlopen error [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond> in downloading page http://bollywoodsalonnj.com/hotmail/newhotmail/hotmail/
# Error<urlopen error [Errno 11001] getaddrinfo failed> in downloading page http://postesecurelogin.posta.it.bancaposta.foo-autenticazione.zrt149k6pqwh4aewmrx1kamldgt0psopjyfdwpzlwwjpmocygzphqstuzcte.faranrfaranr.dyndns.biz/hescientiststravelled/ontworesearchvessels/almostkilometresfrom/ichangtothenearbyhree/loginfilea/foo-autenticazione.php
# Error<urlopen error [Errno 11001] getaddrinfo failed> in downloading page http://postesecurelogin.posta.it.bancaposta.foo-autenticazione.crumlpq9no8sp3giv0qhnngb6rvsh2kolx12dzesxypu5np5enhrt9nauvil.faranrfaranr.dyndns.biz/hescientiststravelled/ontworesearchvessels/almostkilometresfrom/ichangtothenearbyhree/loginfilea/foo-autenticazione.php
# Error<urlopen error ftp error: URLError("ftp error: error_perm('550 ',)",)> in downloading page ftp://host3-61-static.7-79-b.business.telecomitalia.it//mo_terra_import/front.html
# Error<urlopen error [Errno 11001] getaddrinfo failed> in downloading page https://confirmation.account-secureapp.gq/webapps/aa146/websrc
# Error<urlopen error [Errno 11001] getaddrinfo failed> in downloading page https://confirmation.account-secureapp.gq/webapps/9ef75/websrc
# Error<urlopen error [Errno 11001] getaddrinfo failed> in downloading page https://servicee.payment.nz-webapps.com/webapps/6afbe/websrc
# Error<urlopen error [Errno 11001] getaddrinfo failed> in downloading page http://payment-supp-port-gear-best-with-elect-ron-sho-pu-pd-ate-info.rma.tio-nrec-ipe-dis-pu.te.gearbestwithjavastoreelectron.com/webapps/b92e5/websrc
# Error<urlopen error [Errno 11001] getaddrinfo failed> in downloading page https://confirmation.account-secureapp.gq/webapps/7d299/websrc
# Error<urlopen error [Errno 11001] getaddrinfo failed> in downloading page https://confirmation.account-secureapp.gq/webapps/66b13/websrc
# Error<urlopen error [Errno 11002] getaddrinfo failed> in downloading page http://apps-conetions.esy.es/recovery-chekpoint-login.html
# Error<urlopen error [Errno 11002] getaddrinfo failed> in downloading page http://htpps-security.esy.es/recovery-chekpoint-login.html

# %%
import tensorflow

# %%
import gensim
# Out:
# C:\Program Files\Anaconda3\envs\tensorflow\lib\site-packages\gensim\utils.py:860: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
